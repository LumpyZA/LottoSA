# %%
# Importing the libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import pandas as pd

dataset = pd.read_csv('salotto.csv')
dataset = dataset.drop(['DRAW','GAME','WIN1','DIV1','WIN2','DIV2','WIN3','DIV3','WIN4','DIV4','WIN5','DIV5','WIN6','DIV6','WIN7','DIV7','WIN8','DIV8','WIN9','DIV9'],axis=1)

#verify the data
#dataset.head()

# shape
#print(dataset.shape)
# more info on the data
#print(dataset.info())
# descriptions
#print(dataset.describe())

data_to_plot = [dataset['AB1'], dataset['AB2'], dataset['AB3'], dataset['AB4'],dataset['AB5'],dataset['AB6'],dataset['BB']]

# Create a figure instance
fig = plt.figure(1, figsize=(11, 8))

# Create an axes instance
ax = fig.add_subplot(111)

x = np.array(dataset['DATE'])
y = np.array(dataset['AB1'])


line1, = ax.plot(x, y, 'r-')


plt.show()

# %%
# Importing the libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import pandas as pd
from sklearn.linear_model import Lasso

dataset = pd.read_csv('salotto.csv')
dataset = dataset.drop(['DRAW','GAME','WIN1','DIV1','WIN2','DIV2','WIN3','DIV3','WIN4','DIV4','WIN5','DIV5','WIN6','DIV6','WIN7','DIV7','WIN8','DIV8','WIN9','DIV9'],axis=1)

#Now define the model for this dataset for us

def prepareDataset(dataset):
#Keep track of the features
    headers = list(dataset)

#Store the revenues of movies separately in a list
    YIndex = headers.index('DATE')
    datasetMatrix = dataset.as_matrix()
#Make the train and test splits
    datasetTrain = datasetMatrix[0:1500]
    datasetTrainWithoutLabels = np.delete(datasetTrain,YIndex,1)

    labels = datasetTrain[:,YIndex]

    datasetTest = datasetMatrix[1500:datasetMatrix.shape[0]]
    datasetTestWithoutLabels = np.delete(datasetTest,YIndex,1)

    trueLabels = datasetTest[:,YIndex]
    
    return headers,datasetMatrix,datasetTrainWithoutLabels,labels,datasetTest,datasetTestWithoutLabels,trueLabels

regressor = Lasso()
alphas = np.arange(1,50)

steps = [('regressor',regressor)]
pipeline = Pipeline(steps)

parameterGrid = dict(regressor__alpha = alphas)
GridSearchResult = sklearn.grid_search.GridSearchCV(pipeline,param_grid=parameterGrid)

GridSearchResult.fit(datasetTrainWithoutLabels,labels)



predictions = GridSearchResult.predict(datasetTestWithoutLabels)
r2_score(trueLabels, predictions)
return predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a06de24b16a7> in <module>()
#      36
#      37 steps = [('regressor',regressor)]
# ---> 38 pipeline = Pipeline(steps)
#      39
#      40 parameterGrid = dict(regressor__alpha = alphas)
#
# NameError: name 'Pipeline' is not defined

# %%
#import from a dataset the data and use the SVM algorithms

import numpy as np 
from sklearn import preprocessing, cross_validation, neighbors, svm
import pandas as pd

dataset = pd.read_csv('salotto.csv')
dataset = dataset.drop(['DATE','AB2','AB3','AB4','AB5','AB6','GAME','WIN1','DIV1','WIN2','DIV2','WIN3','DIV3','WIN4','DIV4','WIN5','DIV5','WIN6','DIV6','WIN7','DIV7','WIN8','DIV8','WIN9','DIV9'],axis=1)


X = np.array(dataset.drop(['DRAW'],1))
y = np.array(dataset['AB1'])

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size=0.2)

clf = svm.SVC()
clf.fit(X_train, y_train)

accuracy = clf.score(X_test, y_test)
print(accuracy)
# Out:
# 0.21428571428571427

# %%
# using an LTSM model to predict the values....on random 1000 values on the dataset from the first ball in lotto

import numpy as np
from keras.model import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-125-16a03cc44774> in <module>()
#       2
#       3 import numpy as np
# ----> 4 from keras.model import Sequential
#
# ModuleNotFoundError: No module named 'keras'
